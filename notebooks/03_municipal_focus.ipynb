# %% [markdown]
# # 03 Municipal focus
#
# Analisi comunale sugli importi allocati e sui pagamenti PNRR.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

# %%
from scripts.config import INDICATORS_DATA_DIR
from scripts.utils import latest_snapshot, read_csv

# %%
snapshot = latest_snapshot(INDICATORS_DATA_DIR)
municipal = read_csv(INDICATORS_DATA_DIR / snapshot / "municipal_summary.csv")
municipal.shape

# %%
municipal.sort_values("finanziamento_pnrr_allocated", ascending=False).head(30)

# %%
municipal.sort_values("payment_progress_pnrr_allocated", ascending=False).head(30)
