# %% [markdown]
# # 03 Municipal focus
#
# Notebook comunale con parametri, caricamento dati, classifiche e controlli.

# %% [markdown]
# ## Parametri
#
# Modificare snapshot, numero di righe e colonna di ordinamento.

# %%
TOP_N = 30
SNAPSHOT = None
RANKING_COLUMN = 'finanziamento_pnrr_allocated'

# %%
from pathlib import Path
import sys
import pandas as pd
REPO_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
from scripts.config import INDICATORS_DATA_DIR
from scripts.utils import latest_snapshot, read_csv

# %% [markdown]
# ## Caricamento
#
# La tabella comunale è prodotta dalla pipeline in output/data/indicators.

# %%
snapshot = SNAPSHOT or latest_snapshot(INDICATORS_DATA_DIR)
indicator_dir = INDICATORS_DATA_DIR / snapshot
municipal = read_csv(indicator_dir / 'municipal_summary.csv')
municipal.shape

# %% [markdown]
# ## Classifica
#
# La colonna di ordinamento è definita nella sezione parametri.

# %%
municipal[RANKING_COLUMN] = pd.to_numeric(municipal[RANKING_COLUMN], errors='coerce')
municipal.sort_values(RANKING_COLUMN, ascending=False).head(TOP_N)

# %% [markdown]
# ## Controllo colonne disponibili

# %%
pd.DataFrame({'columns': municipal.columns})
