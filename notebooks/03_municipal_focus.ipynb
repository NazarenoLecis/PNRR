# %% [markdown]
# # 03 Municipal focus
#
# Notebook comunale con parametri, caricamento dati e controlli.

# %% [markdown]
# ## Parametri
#
# Modificare i valori nella cella successiva per scegliere snapshot e numero di righe mostrate.

# %%
TOP_N = 30
SNAPSHOT = None

# %%
from pathlib import Path
import sys
import pandas as pd
REPO_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
from scripts.config import INDICATORS_DATA_DIR
from scripts.utils import latest_snapshot, read_csv

# %% [markdown]
# ## Caricamento
#
# Questa cella legge la tabella comunale generata dalla pipeline.

# %%
snapshot = SNAPSHOT or latest_snapshot(INDICATORS_DATA_DIR)
indicator_dir = INDICATORS_DATA_DIR / snapshot
municipal = read_csv(indicator_dir / 'municipal_summary.csv')
municipal.shape

# %% [markdown]
# ## Anteprima

# %%
municipal.head(TOP_N)
