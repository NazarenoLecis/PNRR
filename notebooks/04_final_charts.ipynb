# %% [markdown]
# # 04 Final charts
#
# Notebook per generare e verificare i grafici finali.

# %% [markdown]
# ## Parametri
#
# SNAPSHOT consente di fissare una data. REBUILD_CHARTS rigenera i grafici.

# %%
SNAPSHOT = None
REBUILD_CHARTS = True

# %%
from pathlib import Path
import sys
import pandas as pd
REPO_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
from scripts.config import OUTPUT_CHARTS_DIR
from scripts.src.make_pnrr_charts import make_pnrr_charts
from scripts.utils import latest_snapshot

# %% [markdown]
# ## Generazione
#
# I file vengono salvati nella cartella output/charts dello snapshot.

# %%
chart_dir = make_pnrr_charts(snapshot=SNAPSHOT) if REBUILD_CHARTS else OUTPUT_CHARTS_DIR / (SNAPSHOT or latest_snapshot(OUTPUT_CHARTS_DIR))
chart_dir

# %% [markdown]
# ## File prodotti

# %%
chart_files = sorted(chart_dir.glob('*.png'))
pd.DataFrame({'chart_file': [path.name for path in chart_files], 'bytes': [path.stat().st_size for path in chart_files]})
